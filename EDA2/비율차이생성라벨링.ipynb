# %%
import pandas as pd

# %% [markdown]
# ###승희한테 코드받아서
# 감사의견 라벨링
# 자본잠식 라벨링
# 이자보상배율 라벨링
#
# 라벨링하고 x,y,z체크
#
# 부실 이후 데이터 삭제

# %%
df = pd.read_csv('../dataset2/data2A_첫행날리기전.csv',index_col=0)

# %%
df
# Out:
#                회사명   거래소코드        회계년도 감사의견코드   산업코드                 산업명  \
# 0          (유)가든주류   97082  2019-12-01    NaN  74603      음ㆍ식료품 및 담배 도매업
# 1          (유)가든주류   97082  2020-12-01     QS  74603      음ㆍ식료품 및 담배 도매업
# 2          (유)가든주류   97082  2021-12-01     UQ  74603      음ㆍ식료품 및 담배 도매업
# 3          (유)가든주류   97082  2022-12-01     DU  74603      음ㆍ식료품 및 담배 도매업
# 4       (유)그룹세브코리아   13171  2019-12-01    NaN  74604            생활용품 도매업
# ...            ...     ...         ...    ...    ...                 ...
# 236368  주식회사씨앤케이무역  101008  2021-12-01     UQ  74603      음ㆍ식료품 및 담배 도매업
# 236369  주식회사씨앤케이무역  101008  2022-12-01     UQ  74603      음ㆍ식료품 및 담배 도매업
# 236370  주식회사씨앤케이스틸   69534  2013-12-01    NaN  32402         1차 비철금속 제조업
# 236371  주식회사씨앤케이스틸   69534  2014-12-01     UQ  32402         1차 비철금속 제조업
# 236372  주식회사씨앤케이스틸   69534  2015-12-01     UQ  32402         1차 비철금속 제조업
#
#                설립일  기업규모코드 기업규모명  통계청 한국표준산업분류 코드 10차(대분류)  ...       이자보상배율  \
# 0       1995/04/21    20.0  중소기업                        46  ...   317.000307
# 1       1995/04/21    20.0  중소기업                        46  ...   129.087339
# 2       1995/04/21    20.0  중소기업                        46  ...    28.673265
# 3       1995/04/21    20.0  중소기업                        46  ...  -143.647487
# 4       1997/08/01    30.0  중견기업                        46  ...  2579.052877
# ...            ...     ...   ...                       ...  ...          ...
# 236368  2016/02/04    20.0  중소기업                        46  ...  1107.024396
# 236369  2016/02/04    20.0  중소기업                        46  ...   219.913224
# 236370  2012/08/30    20.0  중소기업                        24  ...          inf
# 236371  2012/08/30    20.0  중소기업                        24  ...   -76.191883
# 236372  2012/08/30    20.0  중소기업                        24  ...  -216.587064
#
#         new_총자본증가율  new_총부채증가율  new_순이익증가율  new_유형자산증가율  new_유동자산증가율  \
# 0              NaN         NaN         NaN          NaN          NaN
# 1       -40.282420   21.151648  -70.107484    11.148926   -10.630559
# 2         8.314190  -15.629253   45.891815   -54.678908     5.330357
# 3      -423.044897   59.915279 -768.377594   -10.698334   -73.982233
# 4              NaN         NaN         NaN          NaN          NaN
# ...            ...         ...         ...          ...          ...
# 236368   34.545318    5.637965   50.319722    38.536363   -29.275829
# 236369    8.813128   38.162111  -67.953021    -3.491868    39.770147
# 236370         NaN         NaN         NaN          NaN          NaN
# 236371 -312.313544   33.040850 -915.726460    16.245616    17.770578
# 236372  194.742986   -6.354382   32.387992    -6.680828   -88.021317
#
#         new_영업이익증가율  new_재고자산증가율  new_매출액증가율  new_비유동자산증가율
# 0               NaN          NaN         NaN           NaN
# 1        -69.101551   -29.657848  -12.726290     17.827456
# 2        -77.809321   -40.316160  -13.697497    -33.543820
# 3      -2113.412714    -8.322652  -13.730562    -49.370357
# 4               NaN          NaN         NaN           NaN
# ...             ...          ...         ...           ...
# 236368    37.541654          NaN   23.139044     37.657285
# 236369   -70.835165          inf    8.318010     23.144748
# 236370          NaN          NaN         NaN           NaN
# 236371  -384.237761          inf  320.604618     16.291248
# 236372   183.570933   -99.621683  178.411377     -6.675828
#
# [235434 rows x 159 columns]

# %% [markdown]
# ### 감사의견코드 라벨링
# 부도 : A
# 정상 : a

# %%
# Step 2 : 회계년도를 datetime
df['회계년도'] = pd.to_datetime(df['회계년도'], format='%Y-%m-%d')
df_sorted = df.sort_values(by=['거래소코드', '회계년도'])

# Step 3 : 감사의견코드 중 DI, DS DU, AG, QS가 존재하면 A 아니면 a
df_sorted['감사의견_y'] = df_sorted['감사의견코드'].apply(lambda x: "A" if x in ['DI', 'DS', 'DU', 'AG', 'QS'] else "a")

# %% [markdown]
# ### 자본잠식률 100% 라벨링
# 부도 : B
# 정상 : b

# %%
# Step 3 : 자본잠식률 100이면 B 아니면 b
df_sorted['자본잠식률_100'] = df_sorted['자본잠식률'].apply(lambda x: "B" if x >= 100 else "b")

df_sorted['자본잠식률_100']
# Out:
# 70560     b
# 70561     b
# 70562     b
# 70563     b
# 70564     b
#          ..
# 221455    b
# 221456    b
# 16765     B
# 16766     B
# 16767     B
# Name: 자본잠식률_100, Length: 235434, dtype: object

# %% [markdown]
# ### 자본잠식률 50% 2년 연속
# 부도 : C
# 정상 : c

# %%
# 데이터셋을 거래소코드와 회계년도 기준으로 정렬
df_sorted.sort_values(by=['거래소코드', '회계년도'], inplace=True)

# 새로운 'Label' 컬럼을 기본값 'c'로 추가
df_sorted['자본잠식률_50'] = 'c'

# 이전 행의 값 초기화
prev_code = None
prev_cap_erode_rate = None

# 각 행을 순회하며 조건에 따라 'Label' 컬럼 설정
for index, row in df_sorted.iterrows():
    current_code = row['거래소코드']
    current_cap_erode_rate = row['자본잠식률']

    # 현재 행과 이전 행이 같은 회사이고, 두 해 모두 자본잠식률이 50 이상인 경우 'C'로 표시
    if current_code == prev_code and current_cap_erode_rate >= 50 and prev_cap_erode_rate >= 50:
        df_sorted.at[index, '자본잠식률_50'] = 'C'

    # 이전 행 값 업데이트
    prev_code = current_code
    prev_cap_erode_rate = current_cap_erode_rate

# 최종 데이터셋 미리보기
df_sorted.head()
# Out:
#             회사명  거래소코드       회계년도 감사의견코드   산업코드         산업명         설립일  \
# 70560  (주)포스코건설  10000 2012-12-01     UQ  64102      토목 건설업  1994/12/01
# 70561  (주)포스코건설  10000 2013-12-01     UQ  64102      토목 건설업  1994/12/01
# 70562  (주)포스코건설  10000 2014-12-01     UQ  64102      토목 건설업  1994/12/01
# 70563  (주)포스코건설  10000 2015-12-01     UQ  64102      토목 건설업  1994/12/01
# 70564  (주)포스코건설  10000 2016-12-01     UQ  64102      토목 건설업  1994/12/01
#
#        기업규모코드 기업규모명  통계청 한국표준산업분류 코드 10차(대분류)  ...   new_순이익증가율  new_유형자산증가율  \
# 70560    10.0   대기업                        41  ...          NaN          NaN
# 70561    10.0   대기업                        41  ...   -71.478710    40.756393
# 70562    10.0   대기업                        41  ...   -86.472926     5.344684
# 70563    10.0   대기업                        41  ...   127.038293    -4.509898
# 70564    10.0   대기업                        41  ... -2616.490936   -10.676382
#
#        new_유동자산증가율  new_영업이익증가율  new_재고자산증가율  new_매출액증가율  new_비유동자산증가율  \
# 70560          NaN          NaN          NaN         NaN           NaN
# 70561   -18.258059    13.631720   -16.164419   14.016854      4.081387
# 70562   -12.449193   -31.415835    -8.092776   -6.396890     17.867219
# 70563     6.351912   -11.590310   -34.770304  -13.012219     -1.042386
# 70564    -5.085581  -173.802637    54.677241  -15.921085     -8.134513
#
#        감사의견_y  자본잠식률_100  자본잠식률_50
# 70560       a          b         c
# 70561       a          b         c
# 70562       a          b         c
# 70563       a          b         c
# 70564       a          b         c
#
# [5 rows x 162 columns]

# %%
df_sorted
# Out:
#              회사명   거래소코드       회계년도 감사의견코드    산업코드                 산업명  \
# 70560   (주)포스코건설   10000 2012-12-01     UQ   64102              토목 건설업
# 70561   (주)포스코건설   10000 2013-12-01     UQ   64102              토목 건설업
# 70562   (주)포스코건설   10000 2014-12-01     UQ   64102              토목 건설업
# 70563   (주)포스코건설   10000 2015-12-01     UQ   64102              토목 건설업
# 70564   (주)포스코건설   10000 2016-12-01     UQ   64102              토목 건설업
# ...          ...     ...        ...    ...     ...                 ...
# 221455   주식회사두루안  101635 2021-12-01     UQ  105802      소프트웨어 개발 및 공급업
# 221456   주식회사두루안  101635 2022-12-01     UQ  105802      소프트웨어 개발 및 공급업
# 16765   넬코리아주식회사  101667 2020-12-01    NaN   64102              토목 건설업
# 16766   넬코리아주식회사  101667 2021-12-01     QS   64102              토목 건설업
# 16767   넬코리아주식회사  101667 2022-12-01     UQ   64102              토목 건설업
#
#                설립일  기업규모코드 기업규모명  통계청 한국표준산업분류 코드 10차(대분류)  ...   new_순이익증가율  \
# 70560   1994/12/01    10.0   대기업                        41  ...          NaN
# 70561   1994/12/01    10.0   대기업                        41  ...   -71.478710
# 70562   1994/12/01    10.0   대기업                        41  ...   -86.472926
# 70563   1994/12/01    10.0   대기업                        41  ...   127.038293
# 70564   1994/12/01    10.0   대기업                        41  ... -2616.490936
# ...            ...     ...   ...                       ...  ...          ...
# 221455  2007/10/15    20.0  중소기업                        58  ...   317.304431
# 221456  2007/10/15    20.0  중소기업                        58  ...   -51.677152
# 16765   2017/08/08    20.0  중소기업                        41  ...          NaN
# 16766   2017/08/08    20.0  중소기업                        41  ...   190.228461
# 16767   2017/08/08     0.0   NaN                        41  ...   -46.690857
#
#         new_유형자산증가율  new_유동자산증가율  new_영업이익증가율  new_재고자산증가율  new_매출액증가율  \
# 70560           NaN          NaN          NaN          NaN         NaN
# 70561     40.756393   -18.258059    13.631720   -16.164419   14.016854
# 70562      5.344684   -12.449193   -31.415835    -8.092776   -6.396890
# 70563     -4.509898     6.351912   -11.590310   -34.770304  -13.012219
# 70564    -10.676382    -5.085581  -173.802637    54.677241  -15.921085
# ...             ...          ...          ...          ...         ...
# 221455    -1.374490    58.085287    -7.162331     7.322329    1.872254
# 221456    54.399781    10.261314  -403.105893    63.082647  -12.227925
# 16765           NaN          NaN          NaN          NaN         NaN
# 16766     13.969112   -23.104733   173.681224   -28.716629  -14.067465
# 16767    -25.593917   -47.054982   -21.655125   -70.730416  -45.895072
#
#         new_비유동자산증가율  감사의견_y  자본잠식률_100  자본잠식률_50
# 70560            NaN       a          b         c
# 70561       4.081387       a          b         c
# 70562      17.867219       a          b         c
# 70563      -1.042386       a          b         c
# 70564      -8.134513       a          b         c
# ...              ...     ...        ...       ...
# 221455     -1.302387       a          b         c
# 221456     27.676594       a          b         c
# 16765            NaN       a          B         c
# 16766      64.013882       A          B         C
# 16767      10.800214       a          B         C
#
# [235434 rows x 162 columns]

# %%
# Step 4: 
def remove_post_default_data(group):
    # 최초 부도 년도 설정
    default_year = group[group['자본잠식률_100'] == 'B']['회계년도'].min()
    
    # default 값이 nan이 아니면 작거나 같은 데이터만 가져옴
    if not pd.isnull(default_year):
        group = group[group['회계년도'] <= default_year]
    
    return group

# 회사명으로 그룹바이 후 함수 적용
df_filtered = df_sorted.groupby('거래소코드').apply(remove_post_default_data).reset_index(drop=True)

df_filtered.head()
# Out:
#         회사명  거래소코드       회계년도 감사의견코드   산업코드         산업명         설립일  기업규모코드  \
# 0  (주)포스코건설  10000 2012-12-01     UQ  64102      토목 건설업  1994/12/01    10.0
# 1  (주)포스코건설  10000 2013-12-01     UQ  64102      토목 건설업  1994/12/01    10.0
# 2  (주)포스코건설  10000 2014-12-01     UQ  64102      토목 건설업  1994/12/01    10.0
# 3  (주)포스코건설  10000 2015-12-01     UQ  64102      토목 건설업  1994/12/01    10.0
# 4  (주)포스코건설  10000 2016-12-01     UQ  64102      토목 건설업  1994/12/01    10.0
#
#   기업규모명  통계청 한국표준산업분류 코드 10차(대분류)  ...   new_순이익증가율  new_유형자산증가율  new_유동자산증가율  \
# 0   대기업                        41  ...          NaN          NaN          NaN
# 1   대기업                        41  ...   -71.478710    40.756393   -18.258059
# 2   대기업                        41  ...   -86.472926     5.344684   -12.449193
# 3   대기업                        41  ...   127.038293    -4.509898     6.351912
# 4   대기업                        41  ... -2616.490936   -10.676382    -5.085581
#
#    new_영업이익증가율  new_재고자산증가율  new_매출액증가율  new_비유동자산증가율  감사의견_y  자본잠식률_100  \
# 0          NaN          NaN         NaN           NaN       a          b
# 1    13.631720   -16.164419   14.016854      4.081387       a          b
# 2   -31.415835    -8.092776   -6.396890     17.867219       a          b
# 3   -11.590310   -34.770304  -13.012219     -1.042386       a          b
# 4  -173.802637    54.677241  -15.921085     -8.134513       a          b
#
#    자본잠식률_50
# 0         c
# 1         c
# 2         c
# 3         c
# 4         c
#
# [5 rows x 162 columns]

# %%
# Step 4: 
def remove_post_default_data(group):
    # 최초 부도 년도 설정
    default_year = group[group['자본잠식률_50'] == 'C']['회계년도'].min()
    
    # default 값이 nan이 아니면 작거나 같은 데이터만 가져옴
    if not pd.isnull(default_year):
        group = group[group['회계년도'] <= default_year]
    
    return group

# 회사명으로 그룹바이 후 함수 적용
df_filtered_1 = df_filtered.groupby('거래소코드').apply(remove_post_default_data).reset_index(drop=True)

df_filtered_1
# Out:
#              회사명   거래소코드       회계년도 감사의견코드    산업코드                 산업명  \
# 0       (주)포스코건설   10000 2012-12-01     UQ   64102              토목 건설업
# 1       (주)포스코건설   10000 2013-12-01     UQ   64102              토목 건설업
# 2       (주)포스코건설   10000 2014-12-01     UQ   64102              토목 건설업
# 3       (주)포스코건설   10000 2015-12-01     UQ   64102              토목 건설업
# 4       (주)포스코건설   10000 2016-12-01     UQ   64102              토목 건설업
# ...          ...     ...        ...    ...     ...                 ...
# 206819   주식회사밸리온  101563 2022-12-01     UQ  137103                 광고업
# 206820   주식회사두루안  101635 2020-12-01    NaN  105802      소프트웨어 개발 및 공급업
# 206821   주식회사두루안  101635 2021-12-01     UQ  105802      소프트웨어 개발 및 공급업
# 206822   주식회사두루안  101635 2022-12-01     UQ  105802      소프트웨어 개발 및 공급업
# 206823  넬코리아주식회사  101667 2020-12-01    NaN   64102              토목 건설업
#
#                설립일  기업규모코드 기업규모명  통계청 한국표준산업분류 코드 10차(대분류)  ...   new_순이익증가율  \
# 0       1994/12/01    10.0   대기업                        41  ...          NaN
# 1       1994/12/01    10.0   대기업                        41  ...   -71.478710
# 2       1994/12/01    10.0   대기업                        41  ...   -86.472926
# 3       1994/12/01    10.0   대기업                        41  ...   127.038293
# 4       1994/12/01    10.0   대기업                        41  ... -2616.490936
# ...            ...     ...   ...                       ...  ...          ...
# 206819  2011/07/29     0.0   NaN                        71  ...  -187.186038
# 206820  2007/10/15    20.0  중소기업                        58  ...          NaN
# 206821  2007/10/15    20.0  중소기업                        58  ...   317.304431
# 206822  2007/10/15    20.0  중소기업                        58  ...   -51.677152
# 206823  2017/08/08    20.0  중소기업                        41  ...          NaN
#
#         new_유형자산증가율  new_유동자산증가율  new_영업이익증가율  new_재고자산증가율  new_매출액증가율  \
# 0               NaN          NaN          NaN          NaN         NaN
# 1         40.756393   -18.258059    13.631720   -16.164419   14.016854
# 2          5.344684   -12.449193   -31.415835    -8.092776   -6.396890
# 3         -4.509898     6.351912   -11.590310   -34.770304  -13.012219
# 4        -10.676382    -5.085581  -173.802637    54.677241  -15.921085
# ...             ...          ...          ...          ...         ...
# 206819   -99.996809    38.874925 -5290.426318          NaN  180.772919
# 206820          NaN          NaN          NaN          NaN         NaN
# 206821    -1.374490    58.085287    -7.162331     7.322329    1.872254
# 206822    54.399781    10.261314  -403.105893    63.082647  -12.227925
# 206823          NaN          NaN          NaN          NaN         NaN
#
#         new_비유동자산증가율  감사의견_y  자본잠식률_100  자본잠식률_50
# 0                NaN       a          b         c
# 1           4.081387       a          b         c
# 2          17.867219       a          b         c
# 3          -1.042386       a          b         c
# 4          -8.134513       a          b         c
# ...              ...     ...        ...       ...
# 206819     46.174475       a          b         c
# 206820           NaN       a          b         c
# 206821     -1.302387       a          b         c
# 206822     27.676594       a          b         c
# 206823           NaN       a          B         c
#
# [206824 rows x 162 columns]

# %%
# 라벨링 조건에 따라 'y' 컬럼 생성
df_filtered_1['y'] = ((df_filtered_1['감사의견_y'] == 'A') | 
        (df_filtered_1['자본잠식률_100'] == 'B') | 
        (df_filtered_1['자본잠식률_50'] == 'C')).astype(int)

# 결과 확인
df_filtered_1[['감사의견_y', '자본잠식률_100', '자본잠식률_50', 'y']]
# Out:
#        감사의견_y 자본잠식률_100 자본잠식률_50  y
# 0           a         b        c  0
# 1           a         b        c  0
# 2           a         b        c  0
# 3           a         b        c  0
# 4           a         b        c  0
# ...       ...       ...      ... ..
# 206819      a         b        c  0
# 206820      a         b        c  0
# 206821      a         b        c  0
# 206822      a         b        c  0
# 206823      a         B        c  1
#
# [206824 rows x 4 columns]

# %%
df_filtered_1.to_csv('../dataset2/data2A_라벨링_첫행날리기전.csv')

# %%
# Step 4: 
def remove_post_default_data(group):
    # 최초 부도 년도 설정
    default_year = group[group['감사의견_y'] == 'A']['회계년도'].min()
    
    # default 값이 nan이 아니면 작거나 같은 데이터만 가져옴
    if not pd.isnull(default_year):
        group = group[group['회계년도'] <= default_year]
    
    return group

# 회사명으로 그룹바이 후 함수 적용
df_filtered_2 = df_filtered_1.groupby('거래소코드').apply(remove_post_default_data).reset_index(drop=True)

df_filtered_2.head()
# Out:
#         회사명  거래소코드       회계년도 감사의견코드   산업코드         산업명         설립일  기업규모코드  \
# 0  (주)포스코건설  10000 2013-12-01     UQ  64102      토목 건설업  1994/12/01    10.0
# 1  (주)포스코건설  10000 2014-12-01     UQ  64102      토목 건설업  1994/12/01    10.0
# 2  (주)포스코건설  10000 2015-12-01     UQ  64102      토목 건설업  1994/12/01    10.0
# 3  (주)포스코건설  10000 2016-12-01     UQ  64102      토목 건설업  1994/12/01    10.0
# 4  (주)포스코건설  10000 2017-12-01     UQ  64102      토목 건설업  1994/12/01    10.0
#
#   기업규모명  통계청 한국표준산업분류 코드 10차(대분류)  ...   new_순이익증가율  new_유형자산증가율  new_유동자산증가율  \
# 0   대기업                        41  ...   -71.478710    40.756393   -18.258059
# 1   대기업                        41  ...   -86.472926     5.344684   -12.449193
# 2   대기업                        41  ...   127.038293    -4.509898     6.351912
# 3   대기업                        41  ... -2616.490936   -10.676382    -5.085581
# 4   대기업                        41  ...  -108.096322     6.969776   -11.399067
#
#    new_영업이익증가율  new_재고자산증가율  new_매출액증가율  new_비유동자산증가율  감사의견_y  자본잠식률_100  \
# 0    13.631720   -16.164419   14.016854      4.081387       a          b
# 1   -31.415835    -8.092776   -6.396890     17.867219       a          b
# 2   -11.590310   -34.770304  -13.012219     -1.042386       a          b
# 3  -173.802637    54.677241  -15.921085     -8.134513       a          b
# 4  -256.938856   -19.424219   14.943191     36.635257       a          b
#
#    자본잠식률_50
# 0         c
# 1         c
# 2         c
# 3         c
# 4         c
#
# [5 rows x 162 columns]

# %%
df_filtered_2[(df_filtered_2['자본잠식률_50'] == 'C')|(df_filtered_2['자본잠식률_100'] == 'B')|(df_filtered_2['감사의견_y'] == 'A')][['회사명','회계년도','이자보상배율','영업이익(손실)','자본잠식률','이자비용','감사의견_y','자본잠식률_100','자본잠식률_50']]
# Out:
#                  회사명       회계년도        이자보상배율    영업이익(손실)        이자비용 감사의견_y  \
# 128         대한상선주식회사 2013-12-01     71.899590  13425909.0  18673137.0      a
# 205          글로웨이(주) 2015-12-01   -948.655837 -24459516.0   2578334.0      A
# 266     주식회사케이티엔지니어링 2013-12-01   1188.781769  16307423.0   1371776.0      A
# 379         프라임개발(주) 2013-12-01    -55.923732 -22778815.0  40731929.0      a
# 390       동양인터내셔널(주) 2013-12-01      1.898714   1020788.0  53762068.0      a
# ...              ...        ...           ...         ...         ...    ...
# 156689    에너콘코리아유한회사 2021-12-01  -6474.321720  -3560359.0     54992.0      A
# 156692        주식회사팩스 2021-12-01 -29358.926289  -2067162.0      7041.0      a
# 156695      주식회사정진애드 2021-12-01    -86.309546   -803768.0    931262.0      a
# 156696   주식회사제이케이글로벌 2021-12-01    217.974930    415785.0    190749.0      A
# 156701      넬코리아주식회사 2021-12-01  -1111.179691  -5354086.0    481838.0      A
#
#        자본잠식률_100 자본잠식률_50
# 128            B        c
# 205            B        c
# 266            b        c
# 379            B        c
# 390            B        c
# ...          ...      ...
# 156689         B        c
# 156692         B        c
# 156695         B        c
# 156696         b        c
# 156701         B        c
#
# [13629 rows x 8 columns]

# %%
df_filtered_2
# Out:
#              회사명   거래소코드       회계년도 감사의견코드    산업코드                 산업명  \
# 0       (주)포스코건설   10000 2013-12-01     UQ   64102              토목 건설업
# 1       (주)포스코건설   10000 2014-12-01     UQ   64102              토목 건설업
# 2       (주)포스코건설   10000 2015-12-01     UQ   64102              토목 건설업
# 3       (주)포스코건설   10000 2016-12-01     UQ   64102              토목 건설업
# 4       (주)포스코건설   10000 2017-12-01     UQ   64102              토목 건설업
# ...          ...     ...        ...    ...     ...                 ...
# 156697   주식회사밸리온  101563 2021-12-01     UQ  137103                 광고업
# 156698   주식회사밸리온  101563 2022-12-01     UQ  137103                 광고업
# 156699   주식회사두루안  101635 2021-12-01     UQ  105802      소프트웨어 개발 및 공급업
# 156700   주식회사두루안  101635 2022-12-01     UQ  105802      소프트웨어 개발 및 공급업
# 156701  넬코리아주식회사  101667 2021-12-01     QS   64102              토목 건설업
#
#                설립일  기업규모코드 기업규모명  통계청 한국표준산업분류 코드 10차(대분류)  ...   new_순이익증가율  \
# 0       1994/12/01    10.0   대기업                        41  ...   -71.478710
# 1       1994/12/01    10.0   대기업                        41  ...   -86.472926
# 2       1994/12/01    10.0   대기업                        41  ...   127.038293
# 3       1994/12/01    10.0   대기업                        41  ... -2616.490936
# 4       1994/12/01    10.0   대기업                        41  ...  -108.096322
# ...            ...     ...   ...                       ...  ...          ...
# 156697  2011/07/29    20.0  중소기업                        71  ...  -474.841406
# 156698  2011/07/29     0.0   NaN                        71  ...  -187.186038
# 156699  2007/10/15    20.0  중소기업                        58  ...   317.304431
# 156700  2007/10/15    20.0  중소기업                        58  ...   -51.677152
# 156701  2017/08/08    20.0  중소기업                        41  ...   190.228461
#
#         new_유형자산증가율  new_유동자산증가율  new_영업이익증가율  new_재고자산증가율  new_매출액증가율  \
# 0         40.756393   -18.258059    13.631720   -16.164419   14.016854
# 1          5.344684   -12.449193   -31.415835    -8.092776   -6.396890
# 2         -4.509898     6.351912   -11.590310   -34.770304  -13.012219
# 3        -10.676382    -5.085581  -173.802637    54.677241  -15.921085
# 4          6.969776   -11.399067  -256.938856   -19.424219   14.943191
# ...             ...          ...          ...          ...         ...
# 156697   -22.549868   -69.592851   -65.782706          NaN   43.594418
# 156698   -99.996809    38.874925 -5290.426318          NaN  180.772919
# 156699    -1.374490    58.085287    -7.162331     7.322329    1.872254
# 156700    54.399781    10.261314  -403.105893    63.082647  -12.227925
# 156701    13.969112   -23.104733   173.681224   -28.716629  -14.067465
#
#         new_비유동자산증가율  감사의견_y  자본잠식률_100  자본잠식률_50
# 0           4.081387       a          b         c
# 1          17.867219       a          b         c
# 2          -1.042386       a          b         c
# 3          -8.134513       a          b         c
# 4          36.635257       a          b         c
# ...              ...     ...        ...       ...
# 156697     67.339978       a          b         c
# 156698     46.174475       a          b         c
# 156699     -1.302387       a          b         c
# 156700     27.676594       a          b         c
# 156701     64.013882       A          B         c
#
# [156702 rows x 162 columns]

# %%
df_filtered_2[df_filtered_2['이자보상배율'].isnull() == True][(df_filtered_2['자본잠식률_50'] == 'C')|(df_filtered_2['자본잠식률_100'] == 'B')|(df_filtered_2['감사의견_y'] == 'A')][['회사명','회계년도','이자보상배율','영업이익(손실)','이자비용','감사의견_y','자본잠식률_100','자본잠식률_50']]
# Out:
# C:\Users\hotte\AppData\Local\Temp\ipykernel_16540\298702462.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_filtered_2[df_filtered_2['이자보상배율'].isnull() == True][(df_filtered_2['자본잠식률_50'] == 'C')|(df_filtered_2['자본잠식률_100'] == 'B')|(df_filtered_2['감사의견_y'] == 'A')][['회사명','회계년도','이자보상배율','영업이익(손실)','이자비용','감사의견_y','자본잠식률_100','자본잠식률_50']]
#                 회사명       회계년도  이자보상배율  영업이익(손실)  이자비용 감사의견_y 자본잠식률_100  \
# 48262      삼척온천주식회사 2019-12-01     NaN       0.0   0.0      a         B
# 56260    디더블유개발주식회사 2015-12-01     NaN       0.0   0.0      a         B
# 65648      (주)함양리조트 2013-12-01     NaN       0.0   0.0      a         B
# 65838   주식회사몬디케이에스피 2021-12-01     NaN       0.0   0.0      a         B
# 66413    (주)아로마엘에스티 2013-12-01     NaN       0.0   0.0      A         b
# 80653          대유SE 2018-12-01     NaN       0.0   0.0      A         b
# 122124     파크호텔주식회사 2022-12-01     NaN       0.0   0.0      A         b
# 131920      주식회사라메종 2016-12-01     NaN       0.0   0.0      a         B
# 150837    세종에스투유한회사 2020-12-01     NaN       0.0   0.0      A         b
# 156678        (주)황지 2021-12-01     NaN       NaN   NaN      A         b
#
#        자본잠식률_50
# 48262         c
# 56260         c
# 65648         c
# 65838         c
# 66413         c
# 80653         C
# 122124        c
# 131920        c
# 150837        c
# 156678        c
