# %%
import pandas as pd

# %%
df = pd.read_csv('../dataset2/data2A_첫행날리기전_라벨링하고부도이후날림.csv', index_col= 0 )

# %%
df
# Out:
#              회사명   거래소코드        회계년도 감사의견코드    산업코드                 산업명  \
# 0       (주)포스코건설   10000  2012-12-01     UQ   64102              토목 건설업
# 1       (주)포스코건설   10000  2013-12-01     UQ   64102              토목 건설업
# 2       (주)포스코건설   10000  2014-12-01     UQ   64102              토목 건설업
# 3       (주)포스코건설   10000  2015-12-01     UQ   64102              토목 건설업
# 4       (주)포스코건설   10000  2016-12-01     UQ   64102              토목 건설업
# ...          ...     ...         ...    ...     ...                 ...
# 177573   주식회사밸리온  101563  2022-12-01     UQ  137103                 광고업
# 177574   주식회사두루안  101635  2020-12-01    NaN  105802      소프트웨어 개발 및 공급업
# 177575   주식회사두루안  101635  2021-12-01     UQ  105802      소프트웨어 개발 및 공급업
# 177576   주식회사두루안  101635  2022-12-01     UQ  105802      소프트웨어 개발 및 공급업
# 177577  넬코리아주식회사  101667  2020-12-01    NaN   64102              토목 건설업
#
#                설립일  기업규모코드 기업규모명  통계청 한국표준산업분류 코드 10차(대분류)  ...   new_순이익증가율  \
# ...

# %%
# 라벨링 조건에 따라 'y' 컬럼 생성
df['y'] = ((df['감사의견_y'] == 'A') | 
        (df['자본잠식률_100'] == 'B') | 
        (df['자본잠식률_50'] == 'C')).astype(int)

# 결과 확인
df[['감사의견_y', '자본잠식률_100', '자본잠식률_50', 'y']].head()
# Out:
#   감사의견_y 자본잠식률_100 자본잠식률_50  y
# 0      a         b        c  0
# 1      a         b        c  0
# 2      a         b        c  0
# 3      a         b        c  0
# 4      a         b        c  0

# %%
df[['감사의견_y', '자본잠식률_100', '자본잠식률_50', 'y']]
# Out:
#        감사의견_y 자본잠식률_100 자본잠식률_50  y
# 0           a         b        c  0
# 1           a         b        c  0
# 2           a         b        c  0
# 3           a         b        c  0
# 4           a         b        c  0
# ...       ...       ...      ... ..
# 177573      a         b        c  0
# 177574      a         b        c  0
# 177575      a         b        c  0
# 177576      a         b        c  0
# 177577      a         B        c  1
#
# [177578 rows x 4 columns]

# %%
df.to_csv('../dataset2/data2A_첫행날리기전_부도이후날리고y라벨링.csv')
