# %%
import pandas as pd

# %%
df = pd.read_csv('../dataset2/data2A_라벨링_첫행날리기전.csv')
df1 = pd.read_csv('../dataset2/data2A_첫행날리고라벨링.csv')

# %%
df
# Out:
#         Unnamed: 0       회사명   거래소코드        회계년도 감사의견코드    산업코드  \
# 0                0  (주)포스코건설   10000  2012-12-01     UQ   64102
# 1                1  (주)포스코건설   10000  2013-12-01     UQ   64102
# 2                2  (주)포스코건설   10000  2014-12-01     UQ   64102
# 3                3  (주)포스코건설   10000  2015-12-01     UQ   64102
# 4                4  (주)포스코건설   10000  2016-12-01     UQ   64102
# ...            ...       ...     ...         ...    ...     ...
# 206819      206819   주식회사밸리온  101563  2022-12-01     UQ  137103
# 206820      206820   주식회사두루안  101635  2020-12-01    NaN  105802
# 206821      206821   주식회사두루안  101635  2021-12-01     UQ  105802
# 206822      206822   주식회사두루안  101635  2022-12-01     UQ  105802
# 206823      206823  넬코리아주식회사  101667  2020-12-01    NaN   64102
#
#                        산업명         설립일  기업규모코드 기업규모명  ...  new_유형자산증가율  \
# 0                   토목 건설업  1994/12/01    10.0   대기업  ...          NaN
# ...

# %%
df1
# Out:
#         Unnamed: 0       회사명   거래소코드        회계년도 감사의견코드    산업코드  \
# 0                0  (주)포스코건설   10000  2013-12-01     UQ   64102
# 1                1  (주)포스코건설   10000  2014-12-01     UQ   64102
# 2                2  (주)포스코건설   10000  2015-12-01     UQ   64102
# 3                3  (주)포스코건설   10000  2016-12-01     UQ   64102
# 4                4  (주)포스코건설   10000  2017-12-01     UQ   64102
# ...            ...       ...     ...         ...    ...     ...
# 202511      202511   주식회사밸리온  101563  2022-12-01     UQ  137103
# 202512      202512   주식회사두루안  101635  2021-12-01     UQ  105802
# 202513      202513   주식회사두루안  101635  2022-12-01     UQ  105802
# 202514      202514  넬코리아주식회사  101667  2021-12-01     QS   64102
# 202515      202515  넬코리아주식회사  101667  2022-12-01     UQ   64102
#
#                        산업명         설립일  기업규모코드 기업규모명  ...   new_순이익증가율  \
# 0                   토목 건설업  1994/12/01    10.0   대기업  ...   -71.478710
# ...

# %%
df3 = pd.merge(df1, df, on=['거래소코드','회계년도'], how='inner')

# %%
df3
# Out:
#         Unnamed: 0_x        회사명_x   거래소코드        회계년도 감사의견코드_x  산업코드_x  \
# 0                  0     (주)포스코건설   10000  2013-12-01       UQ   64102
# 1                  1     (주)포스코건설   10000  2014-12-01       UQ   64102
# 2                  2     (주)포스코건설   10000  2015-12-01       UQ   64102
# 3                  3     (주)포스코건설   10000  2016-12-01       UQ   64102
# 4                  4     (주)포스코건설   10000  2017-12-01       UQ   64102
# ...              ...          ...     ...         ...      ...     ...
# 173901        202509  주식회사제이케이글로벌  101561  2022-12-01       UQ   31002
# 173902        202510      주식회사밸리온  101563  2021-12-01       UQ  137103
# 173903        202511      주식회사밸리온  101563  2022-12-01       UQ  137103
# 173904        202512      주식회사두루안  101635  2021-12-01       UQ  105802
# 173905        202513      주식회사두루안  101635  2022-12-01       UQ  105802
#
#                       산업명_x       설립일_x  기업규모코드_x 기업규모명_x  ...  new_유형자산증가율_y  \
# ...
